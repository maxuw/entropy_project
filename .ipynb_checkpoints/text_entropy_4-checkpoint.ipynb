# %%
import PreprocessText
import EntropyCount

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Preprocesing i liczenie entropi dla naszego dziennika

# %%
# def preprocess_paper(dir_, articles_amount, paper_name):
    
#     list_articles = []
    
#     for n in range(articles_amount):
#         file = str(n) + ".txt"

#         prep = PreprocessText.whole_proces_polish(dir_, file)
#         entropy, amount_tokens = EntropyCount.calculate_entropy_for_all_words(prep)

#         list_this = []
#         list_this.append(n)
#         list_this.append(paper_name)
#         list_this.append(prep[:3])
#         list_this.append(amount_tokens)
#         list_this.append(entropy)
        
#         list_articles.append(list_this)
    
#     return list_articles

# %%
def whole_preprocess_entrpy_entrate(dir_, articles_amount, paper_name):
    list_articles = []

    for n in range(articles_amount):
        file = str(n) + ".txt"

        prep = PreprocessText.whole_proces_polish(dir_, file)
        entropy, amount_tokens = EntropyCount.EntropyCount.calculate_entropy_for_all_words(prep)

        list_this = []
        list_this.append(n)
        list_this.append(paper_name)
        list_this.append(prep[:3])
        list_this.append(amount_tokens)
        list_this.append(entropy)

        list_articles.append(list_this)
        

    return list_articles

# %%
dir_ = "teksty/nasz_dziennik/all_articles/"
paper_name = "Nasz Dziennik"
articles_amount = 52

list_nasz = whole_preprocess_entrpy_entrate(dir_, articles_amount, paper_name)
# Out:
# 0.txt
# 0
# 1.txt
# 1
# 2.txt
# 2
# 3.txt
# 3
# 4.txt
# 4
# 5.txt
# 5
# 6.txt
# 6
# 7.txt
# 7
# 8.txt
# 8
# 9.txt
# 9
# 10.txt
# 10
# 11.txt
# 11
# 12.txt
# 12
# 13.txt
# 13
# 14.txt
# 14
# 15.txt
# 15
# 16.txt
# 16
# 17.txt
# 17
# 18.txt
# 18
# 19.txt
# 19
# 20.txt
# 20
# 21.txt
# 21
# 22.txt
# 22
# 23.txt
# 23
# 24.txt
# 24
# 25.txt
# 25
# 26.txt
# 26
# 27.txt
# 27
# 28.txt
# 28
# 29.txt
# 29
# 30.txt
# 30
# 31.txt
# 31
# 32.txt
# 32
# 33.txt
# 33
# 34.txt
# 34
# 35.txt
# 35
# 36.txt
# 36
# 37.txt
# 37
# 38.txt
# 38
# 39.txt
# 39
# 40.txt
# 40
# 41.txt
# 41
# 42.txt
# 42
# 43.txt
# 43
# 44.txt
# 44
# 45.txt
# 45
# 46.txt
# 46
# 47.txt
# 47
# 48.txt
# 48
# 49.txt
# 49
# 50.txt
# 50
# 51.txt
# 51

# %%
list_nasz[:5]
# Out:
# [[0, 'Nasz Dziennik', ['od', 'poniedziałek', 'w'], 55, 5.41291130431574],
#  [1, 'Nasz Dziennik', ['list', 'otwarty', 'do'], 630, 7.889397660544073],
#  [2, 'Nasz Dziennik', ['obraz', 'Jan', 'Matejka'], 165, 6.728744278027398],
#  [3, 'Nasz Dziennik', ['osoba', 'chcący', 'wziąć'], 167, 6.711364921590839],
#  [4,
#   'Nasz Dziennik',
#   ['Poznański', 'rodzic', 'apelować'],
#   356,
#   7.3228881270056965]]

# %%
df_nasz = pd.DataFrame(list_nasz, columns = ["Numer artykułu", "Nazwa gazety", "Pierwsze lematy", "Ilość tokenów", "Entropia"])

# %%
df_nasz[:10]
# Out:
#    Numer artykułu   Nazwa gazety                  Pierwsze lematy  \
# 0               0  Nasz Dziennik            [od, poniedziałek, w]
# 1               1  Nasz Dziennik              [list, otwarty, do]
# 2               2  Nasz Dziennik            [obraz, Jan, Matejka]
# 3               3  Nasz Dziennik           [osoba, chcący, wziąć]
# 4               4  Nasz Dziennik    [Poznański, rodzic, apelować]
# 5               5  Nasz Dziennik         [policjant, wspólnie, z]
# 6               6  Nasz Dziennik         [Dawid, Kubacki, wygrać]
# 7               7  Nasz Dziennik            [od, sobota, pasażer]
# 8               8  Nasz Dziennik              [rozmowa, z, Paweł]
# 9               9  Nasz Dziennik  [hołd, powstańca, wielkopolski]
#
#    Ilość tokenów  Entropia
# 0             55  5.412911
# 1            630  7.889398
# 2            165  6.728744
# 3            167  6.711365
# 4            356  7.322888
# 5            225  6.662311
# 6            444  7.516913
# 7            353  7.150304
# 8           1047  8.308044
# 9            743  8.164494

# %%
dir_ = "teksty/gazeta_wyborcza/all_articles/"
paper_name = "Gazeta Wyborcza"
articles_amount = 48

list_gw = PreprocessText.preprocess_paper(dir_, articles_amount, paper_name)
# Out:
# 0.txt
# 0
# 1.txt
# 1
# 2.txt
# 2
# 3.txt
# 3
# 4.txt
# 4
# 5.txt
# 5
# 6.txt
# 6
# 7.txt
# 7
# 8.txt
# 8
# 9.txt
# 9
# 10.txt
# 10
# 11.txt
# 11
# 12.txt
# 12
# 13.txt
# 13
# 14.txt
# 14
# 15.txt
# 15
# 16.txt
# 16
# 17.txt
# 17
# 18.txt
# 18
# 19.txt
# 19
# 20.txt
# 20
# 21.txt
# 21
# 22.txt
# 22
# 23.txt
# 23
# 24.txt
# 24
# 25.txt
# 25
# 26.txt
# 26
# 27.txt
# 27
# 28.txt
# 28
# 29.txt
# 29
# 30.txt
# 30
# 31.txt
# 31
# 32.txt
# 32
# 33.txt
# 33
# 34.txt
# 34
# 35.txt
# 35
# 36.txt
# 36
# 37.txt
# 37
# 38.txt
# 38
# 39.txt
# 39
# 40.txt
# 40
# 41.txt
# 41
# 42.txt
# 42
# 43.txt
# 43
# 44.txt
# 44
# 45.txt
# 45
# 46.txt
# 46
# 47.txt
# 47

# %%
df_gw = pd.DataFrame(list_gw, columns = ["Numer artykułu", "Nazwa gazety", "Pierwsze lematy", "Ilość tokenów", "Entropia"])

# %%
df_gw[:10]
# Out:
#    Numer artykułu     Nazwa gazety                      Pierwsze lematy  \
# 0               0  Gazeta Wyborcza               [z, początek, styczeń]
# 1               1  Gazeta Wyborcza           [MEN, zapowiadać, projekt]
# 2               2  Gazeta Wyborcza           [Małżeństwo, z, Sulechowo]
# 3               3  Gazeta Wyborcza               [4, grudzień, kobieta]
# 4               4  Gazeta Wyborcza                  [Prawnik, z, urząd]
# 5               5  Gazeta Wyborcza                [Kulis, wybór, Marek]
# 6               6  Gazeta Wyborcza  [Urzędujący, prezydent, pracowicie]
# 7               7  Gazeta Wyborcza           [prezydent, Andrzej, Duda]
# 8               8  Gazeta Wyborcza                  [Donald, Tusk, nie]
# 9               9  Gazeta Wyborcza        [Martin, Vizcarr, rozpisować]
#
#    Ilość tokenów  Entropia
# 0            813  7.908418
# 1            992  8.178622
# 2            108  5.975823
# 3            146  6.399236
# 4            353  7.206140
# 5            425  7.373707
# 6            737  7.898266
# 7            337  7.433620
# 8           1197  8.574221
# 9            668  7.994052

# %%
enntropy_mean_nd = df_nasz.loc[:,"Entropia"].mean()

# list_en_mean_nd = pd.Series("", "", "", "", enntropy_mean_nd)

# df_nasz = df_nasz.append(list_en_mean_nd)

# %%
df_nasz
# Out:
#     Numer artykułu   Nazwa gazety                     Pierwsze lematy  \
# 0                0  Nasz Dziennik               [od, poniedziałek, w]
# 1                1  Nasz Dziennik                 [list, otwarty, do]
# 2                2  Nasz Dziennik               [obraz, Jan, Matejka]
# 3                3  Nasz Dziennik              [osoba, chcący, wziąć]
# 4                4  Nasz Dziennik       [Poznański, rodzic, apelować]
# 5                5  Nasz Dziennik            [policjant, wspólnie, z]
# 6                6  Nasz Dziennik            [Dawid, Kubacki, wygrać]
# 7                7  Nasz Dziennik               [od, sobota, pasażer]
# 8                8  Nasz Dziennik                 [rozmowa, z, Paweł]
# 9                9  Nasz Dziennik     [hołd, powstańca, wielkopolski]
# 10              10  Nasz Dziennik           [z, Andrzej, Maciejewski]
# 11              11  Nasz Dziennik          [prezydent, Andrzej, Duda]
# 12              12  Nasz Dziennik           [Syryjski, siła, rządowy]
# 13              13  Nasz Dziennik          [prezydent, Andrzej, Duda]
# 14              14  Nasz Dziennik           [Andrzej, Duda, podpisać]
# 15              15  Nasz Dziennik       [wspierać, euroatlantycki, i]
# 16              16  Nasz Dziennik                   [nie, mieć, mowa]
# 17              17  Nasz Dziennik  [francuski, policja, poinformować]
# 18              18  Nasz Dziennik                        [od, 30, do]
# 19              19  Nasz Dziennik            [Lig, Arabska, odrzucić]
# 20              20  Nasz Dziennik                [punktualnie, o, 23]
# 21              21  Nasz Dziennik              [zgodnie, z, piątkowy]
# 22              22  Nasz Dziennik               [z, Stanisław, Ożogo]
# 23              23  Nasz Dziennik              [tak, jak, oczekiwany]
# 24              24  Nasz Dziennik      [brytyjski, parlament, wrócić]
# 25              25  Nasz Dziennik           [z, Andrzej, Maciejewski]
# 26              26  Nasz Dziennik                      [z, prof, dra]
# 27              27  Nasz Dziennik                 [z, dra, Krzysztof]
# 28              28  Nasz Dziennik           [Ewakuacja, Polak, który]
# 29              29  Nasz Dziennik           [z, Andrzej, Maciejewski]
# 30              30  Nasz Dziennik        [posiadanie, myśliwiec, F35]
# 31              31  Nasz Dziennik              [figurka, matka, Boży]
# 32              32  Nasz Dziennik                      [co, łącze, a]
# 33              33  Nasz Dziennik            [Izrael, zrobić, wielki]
# 34              34  Nasz Dziennik           [z, Andrzej, Bogdanowicz]
# 35              35  Nasz Dziennik           [z, Andrzej, Maciejewski]
# 36              36  Nasz Dziennik                     [z, Marek, Ast]
# 37              37  Nasz Dziennik                   [mieć, obawa, że]
# 38              38  Nasz Dziennik                      [z, prof, dra]
# 39              39  Nasz Dziennik                 [w, kolejny, dzień]
# 40              40  Nasz Dziennik              [polski, dziecko, tyć]
# 41              41  Nasz Dziennik                 [lekarz, z, miasto]
# 42              42  Nasz Dziennik                      [z, prof, dra]
# 43              43  Nasz Dziennik              [spór, o, sądownictwo]
# 44              44  Nasz Dziennik                [w, Warszawa, odbyć]
# 45              45  Nasz Dziennik                 [z, dra, Krzysztof]
# 46              46  Nasz Dziennik                     [z, Marek, Ast]
# 47              47  Nasz Dziennik             [Piąty, ognisko, ptasi]
# 48              48  Nasz Dziennik        [mieć, dobrze, przygotowany]
# 49              49  Nasz Dziennik      [Ukraina, zgłosić, pojawienie]
# 50              50  Nasz Dziennik     [Czeski, służba, weterynaryjny]
# 51              51  Nasz Dziennik           [być, podejrzenie, ptasi]
#
#     Ilość tokenów  Entropia
# 0              55  5.412911
# 1             630  7.889398
# 2             165  6.728744
# 3             167  6.711365
# 4             356  7.322888
# 5             225  6.662311
# 6             444  7.516913
# 7             353  7.150304
# 8            1047  8.308044
# 9             743  8.164494
# 10           1051  7.992039
# 11            140  6.136471
# 12            149  6.233613
# 13             98  5.818392
# 14            522  7.502616
# 15            225  6.623040
# 16            238  6.696374
# 17            196  6.710972
# 18            145  6.454678
# 19            327  7.266613
# 20            653  7.745208
# 21            262  7.088175
# 22            880  7.896703
# 23            258  6.841096
# 24            189  6.569000
# 25           1051  7.992039
# 26           1399  8.087905
# 27           1282  8.109968
# 28            270  6.940588
# 29           1352  8.006857
# 30            231  6.712227
# 31           1141  8.304339
# 32            785  7.935334
# 33            129  6.259338
# 34            644  7.857106
# 35           1271  7.958759
# 36            627  7.636110
# 37            227  6.561831
# 38           1143  8.027204
# 39            370  7.328069
# 40            896  8.236641
# 41            205  6.778743
# 42           1399  8.087905
# 43            189  6.737219
# 44            219  6.991775
# 45           1120  7.799584
# 46            953  7.807697
# 47            341  7.070630
# 48            495  7.460493
# 49            180  6.507228
# 50            120  6.284632
# 51            212  6.726596

# %%
enntropy_mean_gw = df_gw.loc[:,"Entropia"].mean()

# %%
l_ent_nd = ["Nasz Dziennik", enntropy_mean_nd]
l_ent_gw = ["Gazeta Wyborcza", enntropy_mean_gw]
l_ent_mean = [l_ent_nd, l_ent_gw]

# %%
l_ent_mean
# Out:
# [['Nasz Dziennik', 7.2240226455326795], ['Gazeta Wyborcza', 7.310297838902798]]

# %%
df_mean = pd.DataFrame(l_ent_mean, columns = ["Nazwa Gazety", "Średnia Entopia"])

# %%
df_mean
# Out:
#       Nazwa Gazety  Średnia Entopia
# 0    Nasz Dziennik         7.224023
# 1  Gazeta Wyborcza         7.310298

# %%
plt.plot(df_nasz.loc[:,"Ilość tokenów"], df_nasz.loc[:,"Entropia"])

# %%
# p1, = host.plot(df_nasz.loc[:,"Ilość tokenów"], df_nasz.loc[:,"Entropia"], "b-", label="Nasz Dziennik")
# p2, = par1.plot(df_gw.loc[:,"Ilość tokenów"], df_gw.loc[:,"Entropia"], "b-", label="Gazeta Wyborcza")

# %%
# plt.plot(df_nasz.loc[:,"Ilość tokenów"].sort_values(by=['Ilość tokenów'], df_nasz.loc[:,"Entropia"], 'r--', df_gw.loc[:,"Ilość tokenów"], df_gw.loc[:,"Entropia"], 'bs-')
# plt.show()

# %%
# df_nasz.sort_values(by=['Ilość tokenów']).loc[:,"Ilość tokenów"]

# %%
# df_nasz.sort_values(by=['Ilość tokenów']).loc[:,"Entropia"]

# %%
df_gw_tokens = df_gw.sort_values(by=['Ilość tokenów'])
df_gw_tokens[:10]
# Out:
#     Numer artykułu     Nazwa gazety                 Pierwsze lematy  \
# 16              16  Gazeta Wyborcza    [przed, główny, uroczystość]
# 22              22  Gazeta Wyborcza            [w, piątek, Andrzej]
# 12              12  Gazeta Wyborcza     [wybory, prezydencki, 2020]
# 2                2  Gazeta Wyborcza      [Małżeństwo, z, Sulechowo]
# 17              17  Gazeta Wyborcza           [Główny, brama, obóz]
# 23              23  Gazeta Wyborcza     [raz, jeszcze, mieszkaniec]
# 41              41  Gazeta Wyborcza   [bank, zdjęcie, ilustracyjny]
# 3                3  Gazeta Wyborcza          [4, grudzień, kobieta]
# 31              31  Gazeta Wyborcza      [Zaćmienie, Księżyc, 2018]
# 20              20  Gazeta Wyborcza  [Małgorzata, KidawaBłońska, i]
#
#     Ilość tokenów  Entropia
# 16             60  5.131402
# 22             96  5.858145
# 12             98  6.030177
# 2             108  5.975823
# 17            133  5.946381
# 23            139  6.294708
# 41            140  6.485433
# 3             146  6.399236
# 31            153  6.490067
# 20            170  6.667549

# %%
df_nd_tokens = df_nasz.sort_values(by=['Ilość tokenów'])
df_nd_tokens[:10]
# Out:
#     Numer artykułu   Nazwa gazety                  Pierwsze lematy  \
# 0                0  Nasz Dziennik            [od, poniedziałek, w]
# 13              13  Nasz Dziennik       [prezydent, Andrzej, Duda]
# 50              50  Nasz Dziennik  [Czeski, służba, weterynaryjny]
# 33              33  Nasz Dziennik         [Izrael, zrobić, wielki]
# 11              11  Nasz Dziennik       [prezydent, Andrzej, Duda]
# 18              18  Nasz Dziennik                     [od, 30, do]
# 12              12  Nasz Dziennik        [Syryjski, siła, rządowy]
# 2                2  Nasz Dziennik            [obraz, Jan, Matejka]
# 3                3  Nasz Dziennik           [osoba, chcący, wziąć]
# 49              49  Nasz Dziennik   [Ukraina, zgłosić, pojawienie]
#
#     Ilość tokenów  Entropia
# 0              55  5.412911
# 13             98  5.818392
# 50            120  6.284632
# 33            129  6.259338
# 11            140  6.136471
# 18            145  6.454678
# 12            149  6.233613
# 2             165  6.728744
# 3             167  6.711365
# 49            180  6.507228

# %%
# df_gw_tokens["Entropia"]

# %%
plt.plot(df_nd_tokens.loc[:,"Ilość tokenów"], df_nd_tokens.loc[:,"Entropia"], 'r-', df_gw_tokens.loc[:,"Ilość tokenów"], df_gw_tokens.loc[:,"Entropia"], 'b-')
plt.xlabel('Ilość Tokenów')
plt.ylabel('Entropia')
plt.savefig('foo.png')
plt.show()
